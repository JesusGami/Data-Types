# %% [markdown]
# ## Case Study: Data Types in Data Science

# %% [markdown]
# The data file, **crime_sampler.csv** contains the date (1st column), block where it occurred (2nd column), primary type of the crime (3rd), description of the crime (4th), description of the location (5th), if an arrest was made (6th), was it a domestic case (7th), and city district (8th).
#
# Here, however, you'll focus only 4 columns: The date, type of crime, location, and whether or not the crime resulted in an arrest.

# %% [markdown]
# #### Reading your data with CSV Reader and Establishing your Data Containers

# %%
import csv

csvfile = open('crime_sampler.csv','r')
crime_data = []

for row in csv.reader(csvfile):
    crime_data.append((row[0], row[2], row[4], row[5]))
    
crime_data.pop(0)

print(crime_data[:10])
# Out:
# [('05/23/2016 05:35:00 PM', 'ASSAULT', 'STREET', 'false'), ('03/26/2016 08:20:00 PM', 'BURGLARY', 'SMALL RETAIL STORE', 'false'), ('04/25/2016 03:05:00 PM', 'THEFT', 'DEPARTMENT STORE', 'true'), ('04/26/2016 05:30:00 PM', 'BATTERY', 'SIDEWALK', 'false'), ('06/19/2016 01:15:00 AM', 'BATTERY', 'SIDEWALK', 'false'), ('05/28/2016 08:00:00 PM', 'BATTERY', 'GAS STATION', 'false'), ('07/03/2016 03:43:00 PM', 'THEFT', 'OTHER', 'false'), ('06/11/2016 06:55:00 PM', 'PUBLIC PEACE VIOLATION', 'STREET', 'true'), ('10/04/2016 10:20:00 AM', 'BATTERY', 'STREET', 'true'), ('02/14/2017 09:00:00 PM', 'CRIMINAL DAMAGE', 'PARK PROPERTY', 'false')]

# %% [markdown]
# #### Find the Months with the Highest Number of Crimes

# %% [markdown]
# Using the **crime_data** list from the prior cell, we'll'll answer a common question that arises when dealing with crime data:
#
# *How many crimes are committed each month?*

# %%
crime_data
# Out:
# [('05/23/2016 05:35:00 PM', 'ASSAULT', 'STREET', 'false'),
#  ('03/26/2016 08:20:00 PM', 'BURGLARY', 'SMALL RETAIL STORE', 'false'),
#  ('04/25/2016 03:05:00 PM', 'THEFT', 'DEPARTMENT STORE', 'true'),
#  ('04/26/2016 05:30:00 PM', 'BATTERY', 'SIDEWALK', 'false'),
#  ('06/19/2016 01:15:00 AM', 'BATTERY', 'SIDEWALK', 'false'),
#  ('05/28/2016 08:00:00 PM', 'BATTERY', 'GAS STATION', 'false'),
#  ('07/03/2016 03:43:00 PM', 'THEFT', 'OTHER', 'false'),
#  ('06/11/2016 06:55:00 PM', 'PUBLIC PEACE VIOLATION', 'STREET', 'true'),
#  ('10/04/2016 10:20:00 AM', 'BATTERY', 'STREET', 'true'),
#  ('02/14/2017 09:00:00 PM', 'CRIMINAL DAMAGE', 'PARK PROPERTY', 'false'),
#  ('03/01/2017 12:29:00 AM', 'ROBBERY', 'CURRENCY EXCHANGE', 'false'),
#  ('12/29/2016 10:00:00 AM', 'ASSAULT', 'APARTMENT', 'false'),
#  ('01/25/2016 12:22:00 AM', 'BATTERY', 'BAR OR TAVERN', 'false'),
#  ('05/20/2016 03:00:00 PM', 'DECEPTIVE PRACTICE', '', 'false'),
#  ('06/28/2016 12:30:00 AM', 'DECEPTIVE PRACTICE', 'BAR OR TAVERN', 'false'),
#  ('09/01/2016 03:00:00 AM', 'OTHER OFFENSE', 'RESIDENCE', 'false'),
#  ('01/09/2017 06:10:00 PM', 'CRIMINAL DAMAGE', 'APARTMENT', 'false'),
#  ('10/21/2016 08:06:00 PM',
#   'OTHER OFFENSE',
#   'NURSING HOME/RETIREMENT HOME',
#   'false'),
#  ('07/30/2016 08:34:00 PM',
#   'BATTERY',
#   'PARKING LOT/GARAGE(NON.RESID.)',
#   'false'),
#  ('11/27/2016 10:00:00 AM', 'CRIM SEXUAL ASSAULT', 'RESIDENCE', 'false'),
#  ('06/09/2016 02:30:00 PM', 'BATTERY', 'SCHOOL, PUBLIC, GROUNDS', 'false'),
#  ('06/12/2016 11:50:00 AM', 'NARCOTICS', 'STREET', 'true'),
#  ('07/13/2016 03:30:00 AM', 'THEFT', 'APARTMENT', 'false'),
#  ('05/24/2016 10:55:00 PM',
#   'BATTERY',
#   'PARKING LOT/GARAGE(NON.RESID.)',
#   'false'),
#  ('09/29/2016 04:00:00 AM',
#   'CRIMINAL DAMAGE',
#   'DRIVEWAY - RESIDENTIAL',
#   'false'),
#  ('07/09/2016 02:00:00 PM', 'MOTOR VEHICLE THEFT', 'STREET', 'false'),
#  ('09/26/2016 12:05:00 AM', 'ROBBERY', 'STREET', 'false'),
#  ('02/11/2017 04:00:00 PM',
#   'DECEPTIVE PRACTICE',
#   'SMALL RETAIL STORE',
#   'false'),
#  ('08/30/2016 09:30:00 AM', 'CRIMINAL DAMAGE', 'RESIDENCE', 'false'),
#  ('09/29/2016 02:00:00 PM', 'ASSAULT', 'GAS STATION', 'false'),
#  ('06/27/2016 08:00:00 PM', 'OTHER OFFENSE', 'RESIDENCE', 'false'),
#  ('06/04/2016 08:45:00 PM', 'THEFT', 'APARTMENT', 'true'),
#  ('09/19/2016 06:05:00 PM', 'ASSAULT', 'STREET', 'false'),
#  ('02/14/2017 08:00:00 PM', 'CRIMINAL DAMAGE', 'STREET', 'false'),
#  ('05/20/2016 06:30:00 PM',
#   'OFFENSE INVOLVING CHILDREN',
#   'RESIDENCE',
#   'false'),
#  ('09/06/2016 01:00:00 PM', 'DECEPTIVE PRACTICE', 'RESIDENCE', 'false'),
#  ('12/29/2016 05:00:00 PM', 'MOTOR VEHICLE THEFT', 'STREET', 'false'),
#  ('09/17/2016 02:45:00 PM', 'THEFT', 'WAREHOUSE', 'true'),
#  ('11/19/2016 10:30:00 PM', 'CRIMINAL DAMAGE', 'RESIDENCE', 'false'),
#  ('01/12/2016 03:43:00 PM',
#   'LIQUOR LAW VIOLATION',
#   'TAVERN/LIQUOR STORE',
#   'true'),
#  ('01/14/2016 05:00:00 PM', 'THEFT', 'CLEANING STORE', 'false'),
#  ('03/04/2017 02:00:00 AM', 'CRIMINAL TRESPASS', 'APARTMENT', 'false'),
#  ('01/13/2017 02:10:00 PM', 'ASSAULT', 'STREET', 'false'),
#  ('10/16/2016 02:30:00 AM', 'BATTERY', 'CTA PLATFORM', 'false'),
#  ('01/22/2017 08:00:00 AM', 'BATTERY', 'HOSPITAL BUILDING/GROUNDS', 'false'),
#  ('02/02/2016 12:40:00 PM', 'ASSAULT', 'SCHOOL, PUBLIC, BUILDING', 'true'),
#  ('07/21/2016 08:00:00 PM', 'CRIMINAL DAMAGE', 'STREET', 'false'),
#  ('09/08/2016 12:09:00 AM', 'BATTERY', 'STREET', 'false'),
#  ('05/07/2016 03:15:00 PM', 'THEFT', 'STREET', 'false'),
#  ('04/19/2016 10:35:00 PM',
#   'WEAPONS VIOLATION',
#   'VEHICLE NON-COMMERCIAL',
#   'true'),
#  ('10/27/2016 11:04:00 AM', 'DECEPTIVE PRACTICE', 'GAS STATION', 'false'),
#  ('08/27/2016 08:30:00 PM', 'BURGLARY', 'APARTMENT', 'false'),
#  ('01/27/2016 06:45:00 AM', 'BATTERY', 'APARTMENT', 'false'),
#  ('02/17/2017 01:49:00 PM', 'THEFT', 'DRUG STORE', 'false'),
#  ('10/13/2016 05:45:00 PM', 'CRIMINAL DAMAGE', 'RESIDENCE', 'false'),
#  ('11/18/2016 10:00:00 AM', 'BURGLARY', 'VACANT LOT/LAND', 'false'),
#  ('08/17/2016 11:00:00 PM',
#   'CRIMINAL DAMAGE',
#   'PARKING LOT/GARAGE(NON.RESID.)',
#   'false'),
#  ('07/11/2016 03:20:00 AM', 'CRIMINAL DAMAGE', 'APARTMENT', 'false'),
#  ('11/25/2016 12:35:00 AM', 'CRIMINAL DAMAGE', 'APARTMENT', 'false'),
#  ('06/18/2016 05:30:00 AM', 'BATTERY', 'RESIDENCE', 'false'),
#  ('02/15/2016 04:45:00 AM', 'BURGLARY', 'RESIDENCE-GARAGE', 'false'),
#  ('12/17/2016 06:30:00 AM', 'BATTERY', 'RESIDENCE', 'false'),
#  ('07/19/2016 12:00:00 AM', 'CRIMINAL DAMAGE', 'RESIDENCE', 'false'),
#  ('01/15/2017 04:00:00 PM',
#   'BURGLARY',
#   'CHURCH/SYNAGOGUE/PLACE OF WORSHIP',
#   'false'),
#  ('05/18/2016 01:48:00 AM', 'CRIMINAL DAMAGE', 'RESTAURANT', 'false'),
#  ('08/11/2016 04:30:00 AM', 'THEFT', 'STREET', 'false'),
#  ('01/10/2016 02:40:00 PM', 'THEFT', 'STREET', 'false'),
#  ('02/14/2016 04:48:00 AM',
#   'DECEPTIVE PRACTICE',
#   'CURRENCY EXCHANGE',
#   'false'),
#  ('02/16/2017 01:20:00 PM', 'THEFT', 'RESTAURANT', 'false'),
#  ('11/12/2016 06:15:00 PM', 'THEFT', 'GROCERY FOOD STORE', 'false'),
#  ('08/28/2016 02:50:00 PM', 'CRIMINAL DAMAGE', 'STREET', 'false'),
#  ('01/11/2016 03:00:00 PM', 'ASSAULT', 'RESIDENCE', 'false'),
#  ('11/20/2016 01:15:00 PM', 'OTHER OFFENSE', 'APARTMENT', 'false'),
#  ('02/25/2016 11:00:00 AM', 'ASSAULT', 'CHA PARKING LOT/GROUNDS', 'false'),
#  ('03/03/2017 07:00:00 PM',
#   'OFFENSE INVOLVING CHILDREN',
#   'RESIDENCE',
#   'false'),
#  ('02/13/2017 10:45:00 AM',
#   'CRIMINAL DAMAGE',
#   'SCHOOL, PUBLIC, BUILDING',
#   'false'),
#  ('09/23/2016 11:28:00 AM', 'THEFT', 'CTA BUS', 'false'),
#  ('03/20/2016 12:57:00 PM', 'OTHER OFFENSE', 'RESIDENCE', 'false'),
#  ('01/14/2017 09:25:00 AM',
#   'ASSAULT',
#   'CHURCH/SYNAGOGUE/PLACE OF WORSHIP',
#   'false'),
#  ('07/22/2016 05:00:00 PM', 'MOTOR VEHICLE THEFT', 'STREET', 'false'),
#  ('03/23/2016 03:50:00 PM', 'BATTERY', 'STREET', 'false'),
#  ('03/27/2016 02:00:00 PM', 'THEFT', 'APARTMENT', 'false'),
#  ('08/10/2016 04:20:00 PM', 'THEFT', 'RESIDENCE', 'false'),
#  ('09/22/2016 03:00:00 PM', 'THEFT', 'APARTMENT', 'false'),
#  ('01/24/2016 08:32:00 PM', 'BATTERY', 'SIDEWALK', 'true'),
#  ('07/05/2016 05:30:00 PM', 'BATTERY', 'CHA PARKING LOT/GROUNDS', 'false'),
#  ('07/29/2016 11:00:00 PM',
#   'DECEPTIVE PRACTICE',
#   'PARKING LOT/GARAGE(NON.RESID.)',
#   'false'),
#  ('10/01/2016 02:10:00 AM', 'BATTERY', 'APARTMENT', 'true'),
#  ('07/03/2016 04:15:00 AM',
#   'ASSAULT',
#   'PARKING LOT/GARAGE(NON.RESID.)',
#   'true'),
#  ('07/17/2016 11:25:00 AM', 'CRIMINAL DAMAGE', 'APARTMENT', 'false'),
#  ('03/18/2016 07:10:00 AM', 'THEFT', 'CTA TRAIN', 'false'),
#  ('04/08/2016 12:49:00 PM',
#   'BATTERY',
#   'PARKING LOT/GARAGE(NON.RESID.)',
#   'true'),
#  ('12/12/2016 12:00:00 PM', 'THEFT', 'CONSTRUCTION SITE', 'false'),
#  ('08/25/2016 06:10:00 PM', 'BATTERY', 'APARTMENT', 'false'),
#  ('04/15/2016 04:21:00 PM', 'THEFT', 'GAS STATION', 'false'),
#  ('02/26/2016 06:00:00 PM', 'BATTERY', 'STREET', 'false'),
#  ('05/16/2016 02:15:00 PM', 'THEFT', 'SMALL RETAIL STORE', 'false'),
#  ('04/07/2016 12:01:00 AM', 'THEFT', 'HOTEL/MOTEL', 'false'),
#  ('08/24/2016 05:13:00 AM', 'CRIMINAL DAMAGE', 'STREET', 'false'),
#  ('12/19/2016 07:00:00 AM', 'BURGLARY', 'APARTMENT', 'false'),
#  ('08/02/2016 10:00:00 AM', 'ROBBERY', 'STREET', 'false'),
#  ('01/20/2017 10:25:00 AM', 'ASSAULT', 'SCHOOL, PUBLIC, BUILDING', 'false'),
#  ('11/09/2016 07:00:00 PM', 'THEFT', 'STREET', 'false'),
#  ('05/20/2016 05:00:00 PM', 'THEFT', 'STREET', 'false'),
#  ('01/21/2017 04:17:00 PM',
#   'THEFT',
#   'POLICE FACILITY/VEH PARKING LOT',
#   'true'),
#  ('01/24/2016 11:00:00 AM', 'BATTERY', 'OTHER', 'true'),
#  ('04/26/2016 05:55:00 AM', 'BATTERY', 'APARTMENT', 'false'),
#  ('01/19/2017 06:00:00 PM', 'THEFT', 'VEHICLE NON-COMMERCIAL', 'false'),
#  ('08/27/2016 03:43:00 AM', 'BATTERY', 'APARTMENT', 'false'),
#  ('07/18/2016 08:00:00 PM', 'NARCOTICS', 'STREET', 'true'),
#  ('07/19/2016 02:15:00 PM', 'THEFT', 'OTHER', 'false'),
#  ('11/01/2016 09:40:00 AM', 'CRIMINAL DAMAGE', 'APARTMENT', 'false'),
#  ('02/04/2016 06:30:00 AM', 'CRIMINAL DAMAGE', 'RESIDENCE', 'false'),
#  ('07/27/2016 11:20:00 PM', 'NARCOTICS', 'SIDEWALK', 'true'),
#  ('03/09/2016 11:00:00 AM',
#   'PUBLIC PEACE VIOLATION',
#   'SCHOOL, PUBLIC, BUILDING',
#   'false'),
#  ('07/11/2016 06:00:00 PM', 'BURGLARY', 'APARTMENT', 'false'),
#  ('02/13/2017 07:00:00 AM', 'ASSAULT', 'APARTMENT', 'false'),
#  ('02/12/2017 07:00:00 PM', 'BATTERY', 'RESIDENCE', 'false'),
#  ('01/05/2017 05:45:00 PM', 'CRIMINAL DAMAGE', 'STREET', 'false'),
#  ('03/04/2017 02:00:00 PM',
#   'THEFT',
#   'PARKING LOT/GARAGE(NON.RESID.)',
#   'false'),
#  ('01/29/2016 05:55:00 PM', 'ASSAULT', 'SIDEWALK', 'false'),
#  ('01/09/2016 12:28:00 AM', 'OTHER OFFENSE', 'STREET', 'true'),
#  ('07/08/2016 02:30:00 AM', 'THEFT', 'STREET', 'false'),
#  ('06/26/2016 01:00:00 AM', 'BATTERY', 'RESIDENCE', 'false'),
#  ('01/11/2017 09:00:00 AM', 'ASSAULT', 'RESIDENCE', 'false'),
#  ('03/11/2016 07:20:00 PM', 'THEFT', 'RESIDENTIAL YARD (FRONT/BACK)', 'false'),
#  ('03/31/2016 11:10:00 AM', 'BATTERY', 'SIDEWALK', 'false'),
#  ('08/25/2016 12:07:00 PM', 'CRIMINAL DAMAGE', 'APARTMENT', 'false'),
#  ('04/13/2016 04:19:00 PM', 'NARCOTICS', 'ALLEY', 'true'),
#  ('08/11/2016 04:00:00 PM', 'BATTERY', 'SIDEWALK', 'false'),
#  ('12/29/2016 07:30:00 AM', 'THEFT', 'STREET', 'false'),
#  ('08/08/2016 09:00:00 AM', 'THEFT', 'CTA TRAIN', 'false'),
#  ('09/08/2016 12:01:00 AM',
#   'CRIMINAL DAMAGE',
#   'PARKING LOT/GARAGE(NON.RESID.)',
#   'false'),
#  ('02/05/2017 05:30:00 AM', 'BATTERY', 'APARTMENT', 'true'),
#  ('01/05/2017 02:00:00 PM', 'OTHER OFFENSE', 'APARTMENT', 'false'),
#  ('10/30/2016 07:45:00 AM',
#   'CRIMINAL TRESPASS',
#   'RESIDENTIAL YARD (FRONT/BACK)',
#   'true'),
#  ('08/30/2016 02:30:00 PM', 'THEFT', 'STREET', 'false'),
#  ('07/06/2016 01:50:00 PM', 'THEFT', 'DEPARTMENT STORE', 'true'),
#  ('12/12/2016 10:15:00 PM', 'BURGLARY', 'VEHICLE NON-COMMERCIAL', 'true'),
#  ('07/28/2016 12:55:00 AM', 'BATTERY', 'BAR OR TAVERN', 'false'),
#  ('06/10/2016 11:35:00 PM', 'BATTERY', 'SIDEWALK', 'false'),
#  ('10/29/2016 02:07:00 AM', 'BATTERY', 'RESIDENCE', 'false'),
#  ('11/07/2016 10:30:00 AM', 'THEFT', 'RESIDENTIAL YARD (FRONT/BACK)', 'false'),
#  ('10/25/2016 03:35:00 AM', 'THEFT', 'GROCERY FOOD STORE', 'false'),
#  ('05/17/2016 11:00:00 AM', 'BATTERY', 'APARTMENT', 'false'),
#  ('06/09/2016 08:05:00 PM', 'THEFT', 'SIDEWALK', 'false'),
#  ('05/25/2016 08:34:00 PM', 'NARCOTICS', 'SIDEWALK', 'true'),
#  ('09/23/2016 10:00:00 PM', 'THEFT', 'STREET', 'false'),
#  ('09/07/2016 06:20:00 PM', 'THEFT', 'OTHER', 'false'),
#  ('02/02/2016 09:30:00 PM',
#   'MOTOR VEHICLE THEFT',
#   'RESIDENTIAL YARD (FRONT/BACK)',
#   'false'),
#  ('06/01/2016 09:00:00 AM', 'DECEPTIVE PRACTICE', 'RESIDENCE', 'false'),
#  ('05/21/2016 02:00:00 PM',
#   'THEFT',
#   'PARKING LOT/GARAGE(NON.RESID.)',
#   'false'),
#  ('12/03/2016 11:15:00 AM', 'THEFT', 'STREET', 'false'),
#  ('09/23/2016 08:47:00 AM', 'OTHER OFFENSE', 'RESIDENCE', 'false'),
#  ('04/08/2016 07:49:00 PM', 'BURGLARY', 'RESIDENCE', 'false'),
#  ('02/25/2016 08:00:00 AM', 'BURGLARY', 'APARTMENT', 'false'),
#  ('04/25/2016 10:00:00 AM', 'DECEPTIVE PRACTICE', 'APARTMENT', 'false'),
#  ('04/13/2016 02:25:00 AM', 'ASSAULT', 'CTA STATION', 'false'),
#  ('05/21/2016 01:00:00 PM', 'DECEPTIVE PRACTICE', 'DEPARTMENT STORE', 'false'),
#  ('01/01/2017 02:39:00 AM', 'BATTERY', 'RESIDENCE', 'true'),
#  ('02/23/2016 02:45:00 PM', 'THEFT', 'SMALL RETAIL STORE', 'true'),
#  ('04/08/2016 09:00:00 AM', 'DECEPTIVE PRACTICE', 'APARTMENT', 'false'),
#  ('10/22/2016 02:00:00 PM', 'ROBBERY', 'STREET', 'false'),
#  ('06/07/2016 09:03:00 PM', 'NARCOTICS', 'VACANT LOT/LAND', 'true'),
#  ('09/23/2016 10:00:00 PM', 'THEFT', 'OTHER', 'false'),
#  ('01/13/2017 05:00:00 AM',
#   'OTHER OFFENSE',
#   'COMMERCIAL / BUSINESS OFFICE',
#   'false'),
#  ('02/17/2016 01:00:00 PM', 'DECEPTIVE PRACTICE', 'STREET', 'false'),
#  ('05/12/2016 07:30:00 PM',
#   'BATTERY',
#   'PARKING LOT/GARAGE(NON.RESID.)',
#   'false'),
#  ('11/04/2016 01:00:00 PM', 'BURGLARY', 'RESIDENCE', 'false'),
#  ('04/12/2016 06:25:00 PM', 'THEFT', 'CTA TRAIN', 'false'),
#  ('01/14/2016 06:21:00 PM',
#   'NARCOTICS',
#   'PARKING LOT/GARAGE(NON.RESID.)',
#   'true'),
#  ('11/15/2016 12:15:00 AM', 'ROBBERY', 'SIDEWALK', 'false'),
#  ('12/15/2016 09:00:00 AM', 'THEFT', 'APARTMENT', 'false'),
#  ('09/27/2016 08:00:00 PM', 'THEFT', 'ALLEY', 'false'),
#  ('06/28/2016 01:00:00 AM', 'ASSAULT', 'APARTMENT', 'false'),
#  ('09/10/2016 12:50:00 PM',
#   'CRIMINAL DAMAGE',
#   'VEHICLE NON-COMMERCIAL',
#   'false'),
#  ('09/30/2016 05:18:00 PM', 'NARCOTICS', 'STREET', 'true'),
#  ('03/24/2016 12:14:00 AM', 'ASSAULT', 'RESIDENCE', 'true'),
#  ('08/13/2016 08:25:00 PM', 'DECEPTIVE PRACTICE', 'OTHER', 'true'),
#  ('02/17/2017 06:00:00 PM', 'THEFT', 'STREET', 'false'),
#  ('08/08/2016 03:00:00 PM',
#   'CRIMINAL DAMAGE',
#   'VEHICLE NON-COMMERCIAL',
#   'false'),
#  ('08/16/2016 07:00:00 PM',
#   'CRIMINAL DAMAGE',
#   'VEHICLE NON-COMMERCIAL',
#   'false'),
#  ('12/13/2016 12:45:00 AM', 'ROBBERY', 'STREET', 'false'),
#  ('10/29/2016 04:00:00 AM', 'BATTERY', 'RESIDENCE', 'false'),
#  ('07/05/2016 10:00:00 AM', 'CRIMINAL DAMAGE', 'APARTMENT', 'false'),
#  ('01/30/2017 04:00:00 PM', 'THEFT', 'GROCERY FOOD STORE', 'true'),
#  ('06/18/2016 05:00:00 AM', 'BATTERY', 'STREET', 'false'),
#  ('02/17/2016 07:45:00 PM', 'OTHER OFFENSE', 'APARTMENT', 'false'),
#  ('09/24/2016 07:30:00 PM', 'ROBBERY', 'STREET', 'false'),
#  ('10/24/2016 08:23:00 PM', 'WEAPONS VIOLATION', 'SIDEWALK', 'false'),
#  ('03/29/2016 10:16:00 AM', 'ASSAULT', 'STREET', 'false'),
#  ('08/15/2016 07:36:00 PM', 'BATTERY', 'BAR OR TAVERN', 'false'),
#  ('05/07/2016 02:00:00 PM',
#   'DECEPTIVE PRACTICE',
#   'SMALL RETAIL STORE',
#   'false'),
#  ('01/30/2016 12:17:00 PM',
#   'NARCOTICS',
#   'PARKING LOT/GARAGE(NON.RESID.)',
#   'true'),
#  

#   'RESIDENTIAL YARD (FRONT/BACK)',
#   'false'),
#  ('08/07/2016 02:50:00 PM', 'BATTERY', 'CONVENIENCE STORE', 'false'),
#  ('01/01/2017 08:10:00 AM',
#   'CRIMINAL DAMAGE',
#   'RESIDENTIAL YARD (FRONT/BACK)',
#   'false'),
#  ('01/21/2016 01:45:00 AM', 'BATTERY', 'APARTMENT', 'false'),
#  ('07/17/2016 04:42:00 AM', 'DECEPTIVE PRACTICE', 'OTHER', 'false'),
#  ('04/25/2016 07:43:00 PM', 'CRIMINAL DAMAGE', 'APARTMENT', 'true'),
#  ('03/02/2016 02:35:00 PM', 'NARCOTICS', 'SIDEWALK', 'true'),
#  ('08/03/2016 03:30:00 PM', 'SEX OFFENSE', 'CTA TRAIN', 'false'),
#  ('03/22/2016 02:00:00 PM',
#   'OTHER OFFENSE',
#   'CTA GARAGE / OTHER PROPERTY',
#   'false'),
#  ('07/16/2016 12:45:00 PM', 'THEFT', 'SIDEWALK', 'false'),
#  ('08/13/2016 02:45:00 AM',
#   'CRIMINAL DAMAGE',
#   'VEHICLE - OTHER RIDE SERVICE',
#   'false'),
#  ('05/18/2016 02:00:00 AM', 'BURGLARY', 'RESIDENCE', 'false'),
#  ('05/12/2016 01:00:00 PM', 'THEFT', 'RESIDENCE PORCH/HALLWAY', 'false'),
#  ('07/20/2016 10:00:00 AM', 'THEFT', 'RESIDENCE', 'false'),
#  ('07/26/2016 02:40:00 AM',
#   'CRIMINAL TRESPASS',
#   'RESIDENCE PORCH/HALLWAY',
#   'true'),
#  ('08/24/2016 12:55:00 AM', 'BATTERY', 'RESIDENCE', 'false'),
#  ('01/09/2016 11:00:00 PM', 'MOTOR VEHICLE THEFT', 'STREET', 'false'),
#  ('01/03/2017 03:38:00 PM', 'WEAPONS VIOLATION', 'SIDEWALK', 'true'),
#  ('09/04/2016 07:00:00 PM', 'THEFT', 'RESTAURANT', 'false'),
#  ('01/02/2016 09:00:00 AM', 'CRIMINAL DAMAGE', 'STREET', 'false'),
#  ('07/30/2016 03:00:00 PM',
#   'MOTOR VEHICLE THEFT',
#   'PARKING LOT/GARAGE(NON.RESID.)',
#   'false'),
#  ('08/31/2016 09:40:00 PM', 'CRIMINAL DAMAGE', 'RESIDENCE', 'false'),
#  ('09/03/2016 12:05:00 AM', 'BATTERY', 'OTHER', 'false'),
#  ('04/21/2016 08:00:00 PM', 'OTHER OFFENSE', 'APARTMENT', 'false'),
#  ('04/24/2016 08:30:00 PM', 'MOTOR VEHICLE THEFT', 'OTHER', 'false'),
#  ('06/12/2016 11:37:00 PM', 'BURGLARY', 'CONVENIENCE STORE', 'false'),
#  ('11/12/2016 12:00:00 PM',
#   'THEFT',
#   'PARKING LOT/GARAGE(NON.RESID.)',
#   'false'),
#  ('02/16/2016 02:10:00 PM', 'THEFT', 'RESIDENCE PORCH/HALLWAY', 'false'),
#  ('05/18/2016 12:00:00 PM', 'DECEPTIVE PRACTICE', 'APARTMENT', 'false'),
#  ('12/19/2016 06:45:00 AM',
#   'MOTOR VEHICLE THEFT',
#   'RESIDENCE-GARAGE',
#   'false'),
#  ('12/23/2016 06:00:00 PM', 'CRIMINAL TRESPASS', 'CTA PLATFORM', 'true'),
#  ('06/19/2016 04:00:00 PM', 'CRIMINAL DAMAGE', 'RESIDENCE', 'false'),
#  ('07/02/2016 10:30:00 AM', 'OTHER OFFENSE', 'APARTMENT', 'false'),
#  ('03/28/2016 01:38:00 AM', 'BATTERY', 'APARTMENT', 'true'),
#  ('08/29/2016 01:00:00 AM', 'THEFT', 'HOSPITAL BUILDING/GROUNDS', 'false'),
#  ('01/02/2017 05:00:00 PM', 'THEFT', 'RESIDENCE-GARAGE', 'false'),
#  ('07/07/2016 02:00:00 PM', 'THEFT', 'GROCERY FOOD STORE', 'true'),
#  ('05/14/2016 07:00:00 PM', 'THEFT', 'GAS STATION', 'false'),
#  ('03/18/2016 02:30:00 AM', 'BATTERY', 'SIDEWALK', 'false'),
#  ('08/19/2016 03:39:00 PM', 'MOTOR VEHICLE THEFT', 'OTHER', 'false'),
#  ('08/19/2016 02:00:00 AM', 'BURGLARY', 'GROCERY FOOD STORE', 'false'),
#  ('07/06/2016 02:30:00 AM', 'CRIMINAL TRESPASS', 'RESIDENCE-GARAGE', 'false'),
#  ('09/30/2016 03:00:00 PM', 'DECEPTIVE PRACTICE', 'STREET', 'false'),
#  ('02/06/2017 03:00:00 PM', 'OTHER OFFENSE', 'RESTAURANT', 'false'),
#  ('07/28/2016 11:17:00 AM', 'DECEPTIVE PRACTICE', 'APARTMENT', 'false'),
#  
2016 09:00:00 AM', 'DECEPTIVE PRACTICE', 'RESIDENCE', 'false'),
#  ('01/13/2017 04:00:00 PM',
#   'OFFENSE INVOLVING CHILDREN',
#   'APARTMENT',
#   'false'),
#  ('05/15/2016 07:00:00 AM', 'BATTERY', 'OTHER', 'false'),
#  ('06/02/2016 01:30:00 PM', 'BATTERY', 'SCHOOL, PRIVATE, BUILDING', 'false'),
#  ('07/02/2016 02:00:00 AM', 'DECEPTIVE PRACTICE', 'STREET', 'false'),
#  ('10/06/2016 10:00:00 PM', 'THEFT', 'VEHICLE NON-COMMERCIAL', 'false'),
#  ('06/13/2016 07:50:00 AM', 'THEFT', 'APARTMENT', 'false'),
#  ('11/28/2016 12:35:00 PM', 'CRIMINAL DAMAGE', 'SIDEWALK', 'false'),
#  ('10/07/2016 10:30:00 PM',
#   'BATTERY',
#   'PARKING LOT/GARAGE(NON.RESID.)',
#   'false'),
#  ('10/31/2016 12:01:00 AM', 'OTHER OFFENSE', 'RESIDENCE', 'false'),
#  ('02/29/2016 09:35:00 PM', 'BATTERY', 'RESIDENCE', 'false'),
#  ('12/07/2016 07:49:00 PM', 'CRIMINAL DAMAGE', 'APARTMENT', 'false'),
#  ('02/27/2017 06:00:00 PM', 'THEFT', 'RESIDENCE', 'false'),
#  ('06/04/2016 08:50:00 PM', 'NARCOTICS', 'SIDEWALK', 'true'),
#  ('02/01/2017 09:15:00 AM', 'DECEPTIVE PRACTICE', 'RESIDENCE', 'false'),
#  ('09/01/2016 08:15:00 PM', 'ASSAULT', 'STREET', 'true'),
#  ('01/27/2016 10:30:00 PM',
#   'BATTERY',
#   'PARKING LOT/GARAGE(NON.RESID.)',
#   'false'),
#  ('12/01/2016 03:37:00 PM', 'OTHER OFFENSE', 'STREET', 'true'),
#  ('04/16/2016 09:15:00 PM', 'BATTERY', 'APARTMENT', 'false'),
#  ('09/13/2016 02:00:00 AM',
#   'OFFENSE INVOLVING CHILDREN',
#   'RESIDENCE',
#   'false'),
#  ('02/06/2017 03:40:00 PM', 'BATTERY', 'ALLEY', 'false'),
#  ('11/13/2016 04:00:00 PM', 'OTHER OFFENSE', 'STREET', 'false'),
#  ('01/03/2017 01:15:00 PM', 'DECEPTIVE PRACTICE', 'RESTAURANT', 'false'),
#  ('05/27/2016 10:30:00 PM', 'BATTERY', 'APARTMENT', 'true'),
#  ('08/06/2016 10:30:00 AM', 'THEFT', 'RESIDENCE', 'false'),
#  ('07/28/2016 10:05:00 PM', 'WEAPONS VIOLATION', 'SIDEWALK', 'true'),
#  ('08/26/2016 10:00:00 PM', 'THEFT', 'RESIDENCE PORCH/HALLWAY', 'false'),
#  ('03/18/2016 01:00:00 AM',
#   'DECEPTIVE PRACTICE',
#   'GOVERNMENT BUILDING/PROPERTY',
#   'false'),
#  ('02/16/2016 10:30:00 PM', 'THEFT', 'ALLEY', 'false'),
#  ('01/13/2017 01:40:00 AM', 'BATTERY', 'RESIDENCE', 'false'),
#  ('10/15/2016 12:04:00 AM', 'OTHER OFFENSE', 'RESIDENCE', 'false'),
#  ('01/27/2016 07:35:00 PM', 'BATTERY', 'STREET', 'true'),
#  ('10/19/2016 11:00:00 AM', 'ASSAULT', 'RESIDENCE-GARAGE', 'false'),
#  ('10/30/2016 07:00:00 AM', 'THEFT', 'GROCERY FOOD STORE', 'true'),
#  ('01/28/2017 04:00:00 PM', 'ROBBERY', 'STREET', 'false'),
#  ('02/19/2017 09:00:00 PM', 'CRIMINAL DAMAGE', 'STREET', 'false'),
#  ('06/07/2016 04:50:00 AM', 'MOTOR VEHICLE THEFT', 'STREET', 'false'),
#  ('06/24/2016 11:40:00 AM', 'BATTERY', 'RESIDENCE', 'false'),
#  ('03/19/2016 04:55:00 AM', 'ROBBERY', 'SIDEWALK', 'false'),
#  ('11/21/2016 10:00:00 PM', 'THEFT', 'APARTMENT', 'false'),
#  ('11/24/2016 02:51:00 PM',
#   'ASSAULT',
#   'RESIDENTIAL YARD (FRONT/BACK)',
#   'false'),
#  ('01/14/2016 02:00:00 AM', 'THEFT', 'STREET', 'false'),
#  ('05/20/2016 06:15:00 PM', 'NARCOTICS', 'SIDEWALK', 'true'),
#  ('06/15/2016 01:30:00 PM', 'THEFT', 'RESTAURANT', 'false'),
#  ('08/06/2016 01:16:00 PM', 'NARCOTICS', 'SIDEWALK', 'true'),
#  ('01/08/2016 10:50:00 AM', 'CRIMINAL DAMAGE', 'STREET', 'false'),
#  ('02/21/2017 03:00:00 PM', 'THEFT', 'STREET', 'false'),
#  ('02/18/2016 09:00:00 AM', 'DECEPTIVE PRACTICE', 'RESIDENCE', 'false'),
#  ('06/02/2016 01:00:00 PM', 'BATTERY', 'RESIDENCE PORCH/HALLWAY', 'false'),
#  ('01/05/2016 03:55:00 AM', 'BURGLARY', 'GROCERY FOOD STORE', 'false'),
#  ('10/06/2016 09:00:00 PM', 'BATTERY', 'APARTMENT', 'false'),
#  ('05/10/2016 06:00:00 PM', 'BURGLARY', 'SCHOOL, PRIVATE, BUILDING', 'false'),
#  ('02/28/2016 10:25:00 PM', 'ASSAULT', 'SIDEWALK', 'false'),
#  ('01/25/2016 11:22:00 AM',
#   'LIQUOR LAW VIOLATION',
#   'TAVERN/LIQUOR STORE',
#   'true'),
#  ('03/13/2016 08:45:00 AM', 'ROBBERY', 'SIDEWALK', 'false'),
#  ('05/09/2016 06:30:00 PM', 'DECEPTIVE PRACTICE', 'RESIDENCE', 'false'),
#  ('11/21/2016 08:00:00 AM', 'THEFT', 'RESIDENCE', 'false'),
#  ('05/13/2016 06:00:00 AM', 'THEFT', 'STREET', 'false'),
#  ('04/06/2016 10:00:00 AM',
#   'THEFT',
#   'PARKING LOT/GARAGE(NON.RESID.)',
#   'false'),
#  ('02/21/2017 08:05:00 PM', 'NARCOTICS', 'SIDEWALK', 'true'),
#  ('09/12/2016 11:27:00 AM', 'OTHER OFFENSE', 'SIDEWALK', 'true'),
#  ('08/28/2016 02:57:00 AM', 'ASSAULT', 'ALLEY', 'true'),
#  ('02/21/2016 01:30:00 PM', 'BATTERY', 'APARTMENT', 'false'),
#  ('10/18/2016 07:30:00 PM', 'THEFT', 'STREET', 'false'),
#  ('04/29/2016 08:20:00 AM', 'NARCOTICS', 'RESIDENCE', 'true'),
#  ('10/05/2016 11:45:00 AM', 'ROBBERY', 'SIDEWALK', 'false'),
#  ('11/25/2016 12:15:00 PM', 'THEFT', 'STREET', 'false'),
#  ('09/12/2016 04:00:00 PM', 'MOTOR VEHICLE THEFT', 'STREET', 'false'),
#  ('03/29/2016 10:35:00 PM', 'ROBBERY', 'SIDEWALK', 'false'),
#  ('01/14/2017 03:57:00 PM', 'THEFT', 'OTHER', 'false'),
#  ('05/27/2016 11:50:00 AM', 'ROBBERY', 'ALLEY', 'false'),
#  ...]

# %%
from collections import Counter
from datetime import datetime

crimes_by_month = Counter()

for crime in crime_data: 
    # Convert the first element of each item into a Python Datetime Object: date
    date = datetime.strptime(crime[0], '%m/%d/%Y %I:%M:%S %p')
    crimes_by_month[date.month] += 1
    
#The 3 most common months for crime
print(crimes_by_month.most_common(3))
# Out:
# [(1, 1948), (2, 1862), (7, 1257)]

# %% [markdown]
# #### Transforming your Data Containers to Month and Location

# %% [markdown]
# Now let's flip **crime_data** list into a dictionary keyed by month with a list of location values for each month, and filter down to the records for the year 2016.

# %%
print(crime_data[1])
print(crime_data[1][2])
# Out:
# ('03/26/2016 08:20:00 PM', 'BURGLARY', 'SMALL RETAIL STORE', 'false')
# SMALL RETAIL STORE

# %%
from collections import defaultdict

locations_by_month = defaultdict(list)

for row in crime_data:
    date = datetime.strptime(row[0], '%m/%d/%Y %I:%M:%S %p')
    if date.year == 2016:
        locations_by_month[date.month].append(row[2])
    
print(locations_by_month)
# Out:
# defaultdict(<class 'list'>, {5: ['STREET', 'GAS STATION', '', 'PARKING LOT/GARAGE(NON.RESID.)', 'RESIDENCE', 'STREET', 'RESTAURANT', 'SMALL RETAIL STORE', 'STREET', 'APARTMENT', 'SIDEWALK', 'PARKING LOT/GARAGE(NON.RESID.)', 'DEPARTMENT STORE', 'PARKING LOT/GARAGE(NON.RESID.)', 'SMALL RETAIL STORE', 'RESIDENCE', 'STREET', 'RESIDENCE', 'APARTMENT', 'RESIDENCE-GARAGE', 'APARTMENT', 'ALLEY', 'HIGHWAY/EXPRESSWAY', 'SIDEWALK', 'POLICE FACILITY/VEH PARKING LOT', 'RESIDENCE', 'STREET', 'APARTMENT', 'RESIDENCE PORCH/HALLWAY', 'STREET', 'RESIDENCE', 'SMALL RETAIL STORE', 'SCHOOL, PUBLIC, BUILDING', 'SIDEWALK', 'SCHOOL, PUBLIC, BUILDING', 'STREET', 'APARTMENT', 'STREET', 'SIDEWALK', 'SMALL RETAIL STORE', 'ALLEY', 'OTHER', 'APARTMENT', 'STREET', 'RESIDENCE', 'GROCERY FOOD STORE', 'SIDEWALK', 'SCHOOL, PUBLIC, BUILDING', 'APARTMENT', 'APARTMENT', 'PARKING LOT/GARAGE(NON.RESID.)', 'RESIDENCE', 'STREET', 'APARTMENT', 'APARTMENT', 'CURRENCY EXCHANGE', 'RESIDENTIAL YARD (FRONT/BACK)', 'ALLEY', 'CTA TRAIN', 'RESIDENCE', 'RESTAURANT', 'OTHER', 'STREET', 'RESIDENCE', 'RESIDENCE PORCH/HALLWAY', 'APARTMENT', 'GAS STATION', 'SCHOOL, PUBLIC, GROUNDS', 'SIDEWALK', 'STREET', 'RESIDENCE-GARAGE', 'RESIDENCE', 'RESIDENCE-GARAGE', 'RESIDENCE', 'OTHER', 'APARTMENT', 'SIDEWALK', 'SCHOOL, PRIVATE, BUILDING', 'RESIDENCE', 'STREET', 'ALLEY', 'RESIDENCE', 'HOTEL/MOTEL', 'SIDEWALK', 'RESIDENCE PORCH/HALLWAY', 'SIDEWALK', 'ALLEY', 'SIDEWALK', 'ALLEY', 'ALLEY', 'RESIDENCE', 'ALLEY', 'CTA BUS', 'DEPARTMENT STORE', 'RESTAURANT', 'RESIDENCE', 'STREET', 'SIDEWALK', 'DEPARTMENT STORE', 'OTHER', 'APARTMENT', 'RESIDENTIAL YARD (FRONT/BACK)', 'HOTEL/MOTEL', 'BAR OR TAVERN', 'APARTMENT', 'STREET', 'STREET', 'APARTMENT', 'OTHER', 'SCHOOL, PRIVATE, BUILDING', 'ABANDONED BUILDING', 'GAS STATION', 'APARTMENT', 'BANK', 'STREET', 'RESIDENCE', 'SMALL RETAIL STORE', 'APARTMENT', 'STREET', 'RESIDENCE', 'STREET', 'STREET', 'RESIDENCE', 'APARTMENT', 'RESTAURANT', 'APARTMENT', 'STREET', 'STREET', 'RESIDENCE', 'ABANDONED BUILDING', 'RESIDENCE', 'AIRPORT TERMINAL UPPER LEVEL - SECURE AREA', 'PARKING LOT/GARAGE(NON.RESID.)', 'SIDEWALK', 'RESIDENCE', 'RESIDENCE', 'RESIDENCE', 'STREET', 'STREET', 'SCHOOL, PUBLIC, BUILDING', 'RESIDENCE', 'STREET', 'SIDEWALK', 'RESIDENTIAL YARD (FRONT/BACK)', 'SMALL RETAIL STORE', 'RESIDENCE', 'PARKING LOT/GARAGE(NON.RESID.)', 'BANK', 'RESIDENCE', 'ALLEY', 'RESTAURANT', 'APARTMENT', 'STREET', 'RESIDENCE PORCH/HALLWAY', 'SIDEWALK', 'DEPARTMENT STORE', 'GAS STATION', 'PARKING LOT/GARAGE(NON.RESID.)', 'PARK PROPERTY', 'RESIDENTIAL YARD (FRONT/BACK)', 'VEHICLE NON-COMMERCIAL', 'STREET', 'STREET', 'SIDEWALK', 'STREET', 'RESIDENCE', 'STREET', 'APARTMENT', 'ATM (AUTOMATIC TELLER MACHINE)', 'STREET', 'SCHOOL, PUBLIC, BUILDING', 'GAS STATION', 'CTA BUS', 'RESIDENCE', 'STREET', 'DEPARTMENT STORE', 'SIDEWALK', 'SIDEWALK', 'STREET', 'RESIDENCE', 'STREET', 'SIDEWALK', 'ALLEY', 'SIDEWALK', 'STREET', 'RESIDENCE', 'APARTMENT', 'ALLEY', 'SIDEWALK', 'STREET', 'STREET', 'OTHER', 'RESIDENCE', 'RESIDENCE', 'SCHOOL, PUBLIC, BUILDING', 'PARKING LOT/GARAGE(NON.RESID.)', 'RESIDENCE', 'ALLEY', 'STREET', 'APARTMENT', '', 'SCHOOL, PUBLIC, BUILDING', 'STREET', 'APARTMENT', 'GROCERY FOOD STORE', 'RESIDENCE', 'STREET', 'GROCERY FOOD STORE', 'APARTMENT', 'STREET', 'STREET', 'APARTMENT', 'STREET', 'STREET', 'RESTAURANT', 'STREET', 'STREET', 'SCHOOL, PUBLIC, GROUNDS', 'SIDEWALK', 'APARTMENT', 'OTHER', 'OTHER', '', 'SIDEWALK', 'STREET', 'STREET', 'STREET', 'SIDEWALK', 'SIDEWALK', 'CURRENCY EXCHANGE', 'SIDEWALK', 'APARTMENT', 'ALLEY', 'STREET', 'RESIDENCE', 'APARTMENT', 'APARTMENT', 'STREET', 'STREET', 'RESIDENCE', 'CTA STATION', 'STREET', 'STREET', 'RESIDENCE', 'GAS STATION', 'RESIDENCE', 'APARTMENT', 'STREET', 'RESIDENCE', 'STREET', 'STREET', 'STREET', 'DEPARTMENT STORE', 'RESIDENCE', 'ALLEY', 'DRUG STORE', 'STREET', 'STREET', 'SCHOOL, PUBLIC, BUILDING', 'RESIDENCE', 'STREET', 'SIDEWALK', 'DEPARTMENT STORE', 'RESIDENCE', 'STREET', 'APARTMENT', 'PARK PROPERTY', 'VEHICLE NON-COMMERCIAL', 'RESIDE ...

# %% [markdown]
# #### Find the Most Common Crimes by Location Type by Month in 2016

# %% [markdown]
# Using the **locations_by_month** dictionary from the prior cell, we'll now determine common crimes by month and location type. Because the dataset is so large, it's a good idea to use Counter to look at an aspect of it in an easier to manageable size and learn more about it.

# %%
# Loop over the items from locations_by_month
for month, locations in locations_by_month.items():
    location_count = Counter(locations)
    print(month)
    print(location_count.most_common(5))
# Out:
# 5
# [('STREET', 241), ('RESIDENCE', 175), ('APARTMENT', 128), ('SIDEWALK', 111), ('OTHER', 41)]
# 3
# [('STREET', 240), ('RESIDENCE', 190), ('APARTMENT', 139), ('SIDEWALK', 99), ('OTHER', 52)]
# 4
# [('STREET', 213), ('RESIDENCE', 171), ('APARTMENT', 152), ('SIDEWALK', 96), ('OTHER', 40)]
# 6
# [('STREET', 245), ('RESIDENCE', 164), ('APARTMENT', 159), ('SIDEWALK', 123), ('PARKING LOT/GARAGE(NON.RESID.)', 44)]
# 7
# [('STREET', 309), ('RESIDENCE', 177), ('APARTMENT', 166), ('SIDEWALK', 125), ('OTHER', 47)]
# 10
# [('STREET', 248), ('RESIDENCE', 206), ('APARTMENT', 122), ('SIDEWALK', 92), ('OTHER', 62)]
# 12
# [('STREET', 207), ('RESIDENCE', 158), ('APARTMENT', 136), ('OTHER', 47), ('SIDEWALK', 46)]
# 1
# [('STREET', 196), ('RESIDENCE', 160), ('APARTMENT', 153), ('SIDEWALK', 72), ('PARKING LOT/GARAGE(NON.RESID.)', 43)]
# 9
# [('STREET', 279), ('RESIDENCE', 183), ('APARTMENT', 144), ('SIDEWALK', 121), ('OTHER', 39)]
# 11
# [('STREET', 236), ('RESIDENCE', 182), ('APARTMENT', 154), ('SIDEWALK', 75), ('OTHER', 41)]
# 8
# [('STREET', 280), ('RESIDENCE', 199), ('APARTMENT', 144), ('SIDEWALK', 109), ('OTHER', 47)]
# 2
# [('STREET', 188), ('RESIDENCE', 159), ('APARTMENT', 144), ('SIDEWALK', 73), ('OTHER', 40)]

# %% [markdown]
# #### Reading your Data with DictReader and Establishing your Data Containers

# %% [markdown]
# The data file, **crime_sampler.csv** contains in positional order: the date, block where it occurred, primary type of the crime, description of the crime, description of the location, if an arrest was made, was it a domestic case, and city district.
#
# We'll now use a DictReader to load up a dictionary to hold your data with the district as the key and the rest of the data in a list.

# %%
csvfile = open('crime_sampler.csv', 'r')

crimes_by_district = defaultdict(list)

for row in csv.DictReader(csvfile):
    # Pop the district from each row: district
    district = row.pop('District')
    # Append the rest of the data to the list for proper district
    crimes_by_district[district].append(row)

# %%
len(crimes_by_district)
# Out:
# 23

# %%
type(crimes_by_district)
# Out:
# collections.defaultdict

# %%
crimes_by_district['14']
# Out:
# [OrderedDict([('Date', '05/23/2016 05:35:00 PM'),
#               ('Block', '024XX W DIVISION ST'),
#               ('Primary Type', 'ASSAULT'),
#               ('Description', 'SIMPLE'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'true')]),
#  OrderedDict([('Date', '09/22/2016 03:00:00 PM'),
#               ('Block', '027XX N SPAULDING AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'FROM BUILDING'),
#               ('Location Description', 'APARTMENT'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '08/24/2016 05:13:00 AM'),
#               ('Block', '033XX W BARRY AVE'),
#               ('Primary Type', 'CRIMINAL DAMAGE'),
#               ('Description', 'TO VEHICLE'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '05/20/2016 05:00:00 PM'),
#               ('Block', '020XX W le moyne st'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'OVER $500'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '07/08/2016 02:30:00 AM'),
#               ('Block', '018XX W EVERGREEN AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', '$500 AND UNDER'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '07/06/2016 01:50:00 PM'),
#               ('Block', '026XX N ELSTON AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'RETAIL THEFT'),
#               ('Location Description', 'DEPARTMENT STORE'),
#               ('Arrest', 'true'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '07/28/2016 12:55:00 AM'),
#               ('Block', '031XX W LOGAN BLVD'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'SIMPLE'),
#               ('Location Description', 'BAR OR TAVERN'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '09/07/2016 06:20:00 PM'),
#               ('Block', '016XX N DAMEN AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'RETAIL THEFT'),
#               ('Location Description', 'OTHER'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '04/13/2016 02:25:00 AM'),
#               ('Block', '026XX N MILWAUKEE AVE'),
#               ('Primary Type', 'ASSAULT'),
#               ('Description', 'SIMPLE'),
#               ('Location Description', 'CTA STATION'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '02/17/2017 06:00:00 PM'),
#               ('Block', '021XX W NORTH AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'OVER $500'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '07/05/2016 10:00:00 AM'),
#               ('Block', '022XX W ARMITAGE AVE'),
#               ('Primary Type', 'CRIMINAL DAMAGE'),
#               ('Description', 'TO PROPERTY'),
#               ('Location Description', 'APARTMENT'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '08/03/2016 08:00:00 AM'),
#               ('Block', '021XX N STAVE ST'),
#               ('Primary Type', 'DECEPTIVE PRACTICE'),
#               ('Description', 'FINANCIAL IDENTITY THEFT OVER $ 300'),
#               ('Location Description', 'RESIDENCE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '06/26/2016 10:43:00 PM'),
#               ('Block', '034XX W DICKENS AVE'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'DOMESTIC BATTERY SIMPLE'),
#               ('Location Description', 'APARTMENT'),
#               ('Arrest', 'true'),
#               ('Domestic', 'true')]),
#  OrderedDict([('Date', '07/31/2016 08:49:00 PM'),
#               ('Block', '026XX W LE MOYNE ST'),
#               ('Primary Type', 'CRIMINAL DAMAGE'),
#               ('Description', 'TO CITY OF CHICAGO PROPERTY'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '10/07/2016 10:57:00 PM'),
#               ('Block', '032XX W WABANSIA AVE'),
#               ('Primary Type', 'OTHER OFFENSE'),
#               ('Description', 'TELEPHONE THREAT'),
#               ('Location Description', 'RESIDENCE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '10/08/2016 11:05:00 PM'),
#               ('Block', '018XX N KIMBALL AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'OVER $500'),
#               ('Location Description', 'ALLEY'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '06/14/2016 04:10:00 PM'),
#               ('Block', '013XX N ASHLAND AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'RETAIL THEFT'),
#               ('Location Description', 'COMMERCIAL / BUSINESS OFFICE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '10/09/2016 09:00:00 PM'),
#               ('Block', '020XX N KEDZIE AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'OVER $500'),
#               ('Location Description', 'ALLEY'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '12/16/2016 12:00:00 AM'),
#               ('Block', '026XX N ELSTON AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'RETAIL THEFT'),
#               ('Location Description', 'DEPARTMENT STORE'),
#               ('Arrest', 'true'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '01/17/2017 05:58:00 PM'),
#               ('Block', '021XX W NORTH AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'OVER $500'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '11/19/2016 09:10:00 AM'),
#               ('Block', '015XX N WASHTENAW AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', '$500 AND UNDER'),
#               ('Location Description', 'VEHICLE NON-COMMERCIAL'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '02/20/2016 04:00:00 PM'),
#               ('Block', '033XX W BELDEN AVE'),
#               ('Primary Type', 'MOTOR VEHICLE THEFT'),
#               ('Description', 'THEFT/RECOVERY: AUTOMOBILE'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '09/24/2016 09:20:00 AM'),
#               ('Block', '017XX W ELLEN ST'),
#               ('Primary Type', 'CRIMINAL DAMAGE'),
#               ('Description', 'TO VEHICLE'),
#               ('Location Description', 'DRIVEWAY - RESIDENTIAL'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '07/17/2016 06:00:00 AM'),
#               ('Block', '024XX N BERNARD ST'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'FROM BUILDING'),
#               ('Location Description', 'RESIDENCE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '02/18/2016 09:15:00 AM'),
#               ('Block', '014XX N MILWAUKEE AVE'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'SIMPLE'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '08/03/2016 03:30:00 PM'),
#               ('Block', '026XX N MILWAUKEE AVE'),
#               ('Primary Type', 'SEX OFFENSE'),
#               ('Description', 'PUBLIC INDECENCY'),
#               ('Location Description', 'CTA TRAIN'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '07/26/2016 02:40:00 AM'),
#               ('Block', '019XX N RICHMOND ST'),
#               ('Primary Type', 'CRIMINAL TRESPASS'),
#               ('Description', 'TO RESIDENCE'),
#               ('Location Description', 'RESIDENCE PORCH/HALLWAY'),
#               ('Arrest', 'true'),
#               ('Domestic', 'true')]),
#  OrderedDict([('Date', '04/19/2016 08:15:00 PM'),
#               ('Block', '021XX W NORTH AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'OVER $500'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '02/16/2016 10:30:00 PM'),
#               ('Block', '022XX W FULLERTON AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', '$500 AND UNDER'),
#               ('Location Description', 'ALLEY'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '01/06/2017 06:16:00 PM'),
#               ('Block', '033XX W SCHUBERT AVE'),
#               ('Primary Type', 'ROBBERY'),
#               ('Description', 'ATTEMPT: ARMED-KNIFE/CUT INSTR'),
#               ('Location Description', 'APARTMENT'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '04/16/2016 05:47:00 AM'),
#               ('Block', '013XX N PAULINA ST'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'RETAIL THEFT'),
#               ('Location Description', 'GROCERY FOOD STORE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '06/05/2016 03:00:00 PM'),
#               ('Block', '015XX N MAGNOLIA AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', '$500 AND UNDER'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '02/18/2017 05:00:00 AM'),
#               ('Block', '015XX N CAMPBELL AVE'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'DOMESTIC BATTERY SIMPLE'),
#               ('Location Description', 'APARTMENT'),
#               ('Arrest', 'false'),
#               ('Domestic', 'true')]),
#  OrderedDict([('Date', '11/29/2016 02:42:00 PM'),
#               ('Block', '017XX N WESTERN AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', '$500 AND UNDER'),
#               ('Location Description', 'APARTMENT'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '05/26/2016 06:10:00 PM'),
#               ('Block', '016XX N ASHLAND AVE'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'SIMPLE'),
#               ('Location Description', 'CTA BUS'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '02/24/2017 01:00:00 PM'),
#               ('Block', '015XX N FAIRFIELD AVE'),
#               ('Primary Type', 'BURGLARY'),
#               ('Description', 'UNLAWFUL ENTRY'),
#               ('Location Description', 'APARTMENT'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '02/07/2017 05:50:00 PM'),
#               ('Block', '022XX N ELSTON AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'FROM BUILDING'),
#               ('Location Description', 'OTHER'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '09/30/2016 06:00:00 PM'),
#               ('Block', '035XX W DICKENS AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'OVER $500'),
#               ('Location Description', 'APARTMENT'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '12/02/2016 01:30:00 PM'),
#               ('Block', '024XX N CALIFORNIA AVE'),
#               ('Primary Type', 'DECEPTIVE PRACTICE'),
#               ('Description', 'BOGUS CHECK'),
#               ('Location Description', 'OTHER'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '02/15/2017 09:00:00 AM'),
#               ('Block', '024XX W DIVISION ST'),
#               ('Primary Type', 'THEFT'),
#               ('Description', '$500 AND UNDER'),
#               ('Location Description', 'OTHER'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '01/27/2016 05:17:00 PM'),
#               ('Block', '016XX W NORTH AVE'),
#               ('Primary Type', 'DECEPTIVE PRACTICE'),
#               ('Description', 'FRAUD OR CONFIDENCE GAME'),
#               ('Location Description', 'GAS STATION'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '06/14/2016 07:00:00 AM'),
#               ('Block', '034XX W DRUMMOND PL'),
#               ('Primary Type', 'DECEPTIVE PRACTICE'),
#               ('Description', 'FRAUD OR CONFIDENCE GAME'),
#               ('Location Description', 'APARTMENT'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '02/16/2016 12:01:00 AM'),
#               ('Block', '020XX N POINT ST'),
#               ('Primary Type', 'DECEPTIVE PRACTICE'),
#               ('Description', 'CREDIT CARD FRAUD'),
#               ('Location Description', 'OTHER'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '03/16/2016 09:30:00 PM'),
#               ('Block', '016XX W WABANSIA AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', '$500 AND UNDER'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '09/18/2016 10:48:00 PM'),
#               ('Block', '014XX N CALIFORNIA AVE'),
#               ('Primary Type', 'ASSAULT'),
#               ('Description', 'AGGRAVATED: HANDGUN'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '06/17/2016 10:00:00 PM'),
#               ('Block', '033XX W WABANSIA AVE'),
#               ('Primary Type', 'CRIMINAL DAMAGE'),
#               ('Description', 'TO VEHICLE'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '07/28/2016 02:00:00 PM'),
#               ('Block', '028XX N WESTERN AVE'),
#               ('Primary Type', 'BURGLARY'),
#               ('Description', 'UNLAWFUL ENTRY'),
#               ('Location Description', 'OTHER'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '02/06/2016 11:00:00 PM'),
#               ('Block', '012XX N PAULINA ST'),
#               ('Primary Type', 'CRIMINAL DAMAGE'),
#               ('Description', 'TO VEHICLE'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '11/17/2016 04:13:00 PM'),
#               ('Block', '026XX W GEORGE ST'),
#               ('Primary Type', 'OTHER OFFENSE'),
#               ('Description', 'HARASSMENT BY ELECTRONIC MEANS'),
#               ('Location Description', 'RESIDENCE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '09/04/2016 10:00:00 PM'),
#               ('Block', '033XX W NORTH AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', '$500 AND UNDER'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '07/29/2016 07:45:00 PM'),
#               ('Block', '026XX W HIRSCH ST'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'DOMESTIC BATTERY SIMPLE'),
#               ('Location Description', 'RESIDENTIAL YARD (FRONT/BACK)'),
#               ('Arrest', 'false'),
#               ('Domestic', 'true')]),
#  OrderedDict([('Date', '01/10/2017 09:00:00 PM'),
#               ('Block', '026XX N ELSTON AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'POCKET-PICKING'),
#               ('Location Description', 'DEPARTMENT STORE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '06/02/2016 10:08:00 PM'),
#               ('Block', '019XX N WESTERN AVE'),
#               ('Primary Type', 'ASSAULT'),
#               ('Description', 'PRO EMP HANDS NO/MIN INJURY'),
#               ('Location Description', 'CTA STATION'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '07/26/2016 04:37:00 AM'),
#               ('Block', '014XX N WOOD ST'),
#               ('Primary Type', 'OTHER OFFENSE'),
#               ('Description', 'HARASSMENT BY ELECTRONIC MEANS'),
#               ('Location Description', 'RESIDENCE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'true')]),
#  OrderedDict([('Date', '09/02/2016 09:40:00 PM'),
#               ('Block', '015XX N WASHTENAW AVE'),
#               ('Primary Type', 'OTHER OFFENSE'),
#               ('Description', 'PAROLE VIOLATION'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'true'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '03/04/2017 12:01:00 AM'),
#               ('Block', '013XX W POTOMAC AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', '$500 AND UNDER'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '01/13/2017 07:15:00 PM'),
#               ('Block', '034XX W DIVERSEY AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', '$500 AND UNDER'),
#               ('Location Description', 'SMALL RETAIL STORE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '04/30/2016 12:30:00 AM'),
#               ('Block', '026XX N ELSTON AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', '$500 AND UNDER'),
#               ('Location Description', 'GROCERY FOOD STORE'),
#               ('Arrest', 'true'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '10/15/2016 08:30:00 PM'),
#               ('Block', '022XX N DRAKE AVE'),
#               ('Primary Type', 'ROBBERY'),
#               ('Description', 'STRONGARM - NO WEAPON'),
#               ('Location Description', 'SIDEWALK'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '03/01/2017 07:04:00 PM'),
#               ('Block', '032XX W LE MOYNE ST'),
#               ('Primary Type', 'BURGLARY'),
#               ('Description', 'FORCIBLE ENTRY'),
#               ('Location Description', 'APARTMENT'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '02/28/2017 04:32:00 AM'),
#               ('Block', '027XX N ST LOUIS AVE'),
#               ('Primary Type', 'OTHER OFFENSE'),
#               ('Description', 'HARASSMENT BY ELECTRONIC MEANS'),
#               ('Location Description', 'OTHER'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '06/09/2016 06:00:00 PM'),
#               ('Block', '028XX N WESTERN AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'FROM BUILDING'),
#               ('Location Description', 'OTHER'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '05/19/2016 11:00:00 AM'),
#               ('Block', '025XX W BLOOMINGDALE AVE'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'SIMPLE'),
#               ('Location Description', 'SIDEWALK'),
#               ('Arrest', 'true'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '10/06/2016 06:25:00 AM'),
#               ('Block', '012XX N MILWAUKEE AVE'),
#               ('Primary Type', 'CRIMINAL TRESPASS'),
#               ('Description', 'TO STATE SUP LAND'),
#               ('Location Description', 'CTA STATION'),
#               ('Arrest', 'true'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '02/26/2016 12:40:00 AM'),
#               ('Block', '028XX W DIVERSEY AVE'),
#               ('Primary Type', 'CRIMINAL DAMAGE'),
#               ('Description', 'TO VEHICLE'),
#               ('Location Description', 'PARKING LOT/GARAGE(NON.RESID.)'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '10/15/2016 12:30:00 PM'),
#               ('Block', '016XX N CAMPBELL AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', '$500 AND UNDER'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '06/13/2016 01:45:00 PM'),
#               ('Block', '014XX N MILWAUKEE AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', '$500 AND UNDER'),
#               ('Location Description', 'OTHER'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '07/10/2016 11:00:00 AM'),
#               ('Block', '013XX N WESTERN AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'OVER $500'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '09/07/2016 07:00:00 AM'),
#               ('Block', '025XX N CAMPBELL AVE'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'DOMESTIC BATTERY SIMPLE'),
#               ('Location Description', 'APARTMENT'),
#               ('Arrest', 'true'),
#               ('Domestic', 'true')]),
#  OrderedDict([('Date', '09/16/2016 11:55:00 AM'),
#               ('Block', '020XX N SPAULDING AVE'),
#               ('Primary Type', 'BURGLARY'),
#               ('Description', 'UNLAWFUL ENTRY'),
#               ('Location Description', 'APARTMENT'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '01/12/2017 12:20:00 PM'),
#               ('Block', '013XX N ELSTON AVE'),
#               ('Primary Type', 'MOTOR VEHICLE THEFT'),
#               ('Description', 'AUTOMOBILE'),
#               ('Location Description', 'PARKING LOT/GARAGE(NON.RESID.)'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '11/15/2016 11:00:00 PM'),
#               ('Block', '035XX W BELDEN AVE'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'DOMESTIC BATTERY SIMPLE'),
#               ('Location Description', 'APARTMENT'),
#               ('Arrest', 'false'),
#               ('Domestic', 'true')]),
#  OrderedDict([('Date', '12/05/2016 07:00:00 PM'),
#               ('Block', '034XX W SHAKESPEARE AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', '$500 AND UNDER'),
#               ('Location Description', 'RESIDENTIAL YARD (FRONT/BACK)'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '07/15/2016 11:10:00 AM'),
#               ('Block', '033XX W EVERGREEN AVE'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'SIMPLE'),
#               ('Location Description', 'CHA PARKING LOT/GROUNDS'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '06/11/2016 07:30:00 PM'),
#               ('Block', '022XX N ST LOUIS AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', '$500 AND UNDER'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '01/21/2017 01:05:00 PM'),
#               ('Block', '021XX N MOZART ST'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'FROM BUILDING'),
#               ('Location Description', 'RESIDENCE PORCH/HALLWAY'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '05/15/2016 10:00:00 PM'),
#               ('Block', '026XX W LOGAN BLVD'),
#               ('Primary Type', 'CRIMINAL TRESPASS'),
#               ('Description', 'TO VEHICLE'),
#               ('Location Description', 'VEHICLE NON-COMMERCIAL'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '02/13/2016 01:00:00 PM'),
#               ('Block', '014XX N OAKLEY BLVD'),
#               ('Primary Type', 'THEFT'),
#               ('Description', '$500 AND UNDER'),
#               ('Location Description', 'RESIDENTIAL YARD (FRONT/BACK)'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '08/30/2016 10:00:00 PM'),
#               ('Block', '016XX N ARTESIAN AVE'),
#               ('Primary Type', 'MOTOR VEHICLE THEFT'),
#               ('Description', 'AUTOMOBILE'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '08/25/2016 05:30:00 PM'),
#               ('Block', '016XX N ADA ST'),
#               ('Primary Type', 'CRIMINAL DAMAGE'),
#               ('Description', 'TO VEHICLE'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '06/16/2016 04:30:00 PM'),
#               ('Block', '032XX W PALMER ST'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'SIMPLE'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '12/23/2016 10:00:00 AM'),
#               ('Block', '035XX W BARRY AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', '$500 AND UNDER'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '02/18/2017 05:30:00 PM'),
#               ('Block', '035XX W DIVERSEY AVE'),
#               ('Primary Type', 'SEX OFFENSE'),
#               ('Description', 'AGG CRIMINAL SEXUAL ABUSE'),
#               ('Location Description', 'OTHER'),
#               ('Arrest', 'true'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '07/21/2016 10:25:00 AM'),
#               ('Block', '027XX W DIVISION ST'),
#               ('Primary Type', 'ASSAULT'),
#               ('Description', 'SIMPLE'),
#               ('Location Description', 'SMALL RETAIL STORE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '02/03/2016 09:00:00 PM'),
#               ('Block', '018XX N MARSHFIELD AVE'),
#               ('Primary Type', 'CRIMINAL DAMAGE'),
#               ('Description', 'TO VEHICLE'),
#               ('Location Description', 'OTHER'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '06/08/2016 03:03:00 PM'),
#               ('Block', '025XX W CORTLAND ST'),
#               ('Primary Type', 'ASSAULT'),
#               ('Description', 'AGGRAVATED: HANDGUN'),
#               ('Location Description', 'SIDEWALK'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '06/03/2016 11:40:00 AM'),
#               ('Block', '032XX W EVERGREEN AVE'),
#               ('Primary Type', 'CRIMINAL TRESPASS'),
#               ('Description', 'TO RESIDENCE'),
#               ('Location Description', 'APARTMENT'),
#               ('Arrest', 'true'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '01/20/2016 01:00:00 PM'),
#               ('Block', '034XX W DIVISION ST'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'SIMPLE'),
#               ('Location Description', 'OTHER'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '07/21/2016 01:10:00 PM'),
#               ('Block', '033XX W NORTH AVE'),
#               ('Primary Type', 'DECEPTIVE PRACTICE'),
#               ('Description', 'FRAUD OR CONFIDENCE GAME'),
#               ('Location Description', 'BANK'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '06/19/2016 05:00:00 PM'),
#               ('Block', '017XX N WESTERN AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', '$500 AND UNDER'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '02/01/2017 06:13:00 AM'),
#               ('Block', '014XX N CAMPBELL AVE'),
#               ('Primary Type', 'OTHER OFFENSE'),
#               ('Description', 'TELEPHONE THREAT'),
#               ('Location Description', 'OTHER'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '02/06/2017 06:45:00 AM'),
#               ('Block', '020XX W FULLERTON AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'OVER $500'),
#               ('Location Description', 'PARKING LOT/GARAGE(NON.RESID.)'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '05/14/2016 10:00:00 PM'),
#               ('Block', '022XX W NORTH AVE'),
#               ('Primary Type', 'CRIMINAL DAMAGE'),
#               ('Description', 'TO VEHICLE'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '07/10/2016 04:20:00 AM'),
#               ('Block', '021XX W SCHILLER ST'),
#               ('Primary Type', 'ROBBERY'),
#               ('Description', 'ARMED: HANDGUN'),
#               ('Location Description', 'SIDEWALK'),
#               ('Arrest', 'true'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '02/09/2016 06:00:00 PM'),
#               ('Block', '028XX N MILWAUKEE AVE'),
#               ('Primary Type', 'CRIMINAL DAMAGE'),
#               ('Description', 'TO PROPERTY'),
#               ('Location Description', 'MEDICAL/DENTAL OFFICE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '12/26/2016 07:30:00 PM'),
#               ('Block', '021XX N CAMPBELL AVE'),
#               ('Primary Type', 'CRIMINAL DAMAGE'),
#               ('Description', 'TO VEHICLE'),
#               ('Location Description', 'PARKING LOT/GARAGE(NON.RESID.)'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '01/11/2017 12:44:00 AM'),
#               ('Block', '023XX N MILWAUKEE AVE'),
#               ('Primary Type', 'BURGLARY'),
#               ('Description', 'FORCIBLE ENTRY'),
#               ('Location Description', 'OTHER'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '11/10/2016 08:00:00 AM'),
#               ('Block', '020XX N WHIPPLE ST'),
#               ('Primary Type', 'CRIMINAL DAMAGE'),
#               ('Description', 'TO PROPERTY'),
#               ('Location Description', 'RESIDENTIAL YARD (FRONT/BACK)'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '04/11/2016 08:00:00 AM'),
#               ('Block', '017XX N DAMEN AVE'),
#               ('Primary Type', 'DECEPTIVE PRACTICE'),
#               ('Description', 'FINANCIAL IDENTITY THEFT OVER $ 300'),
#               ('Location Description', ''),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '02/04/2017 05:00:00 PM'),
#               ('Block', '020XX N STAVE ST'),
#               ('Primary Type', 'BURGLARY'),
#               ('Description', 'UNLAWFUL ENTRY'),
#               ('Location Description', 'RESIDENCE-GARAGE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '01/30/2017 07:25:00 PM'),
#               ('Block', '017XX W NORTH AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'FROM BUILDING'),
#               ('Location Description', 'ATHLETIC CLUB'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '04/16/2016 08:55:00 AM'),
#               ('Block', '023XX N LEAVITT ST'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'OVER $500'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '10/28/2016 05:30:00 PM'),
#               ('Block', '025XX W NORTH AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'FROM BUILDING'),
#               ('Location Description', 'DEPARTMENT STORE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '07/17/2016 10:00:00 AM'),
#               ('Block', '016XX N FAIRFIELD AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'FROM BUILDING'),
#               ('Location Description', 'RESIDENCE PORCH/HALLWAY'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '01/06/2016 08:31:00 PM'),
#               ('Block', '018XX N WASHTENAW AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', '$500 AND UNDER'),
#               ('Location Description', 'RESIDENTIAL YARD (FRONT/BACK)'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '10/22/2016 10:39:00 PM'),
#               ('Block', '035XX W WABANSIA AVE'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'DOMESTIC BATTERY SIMPLE'),
#               ('Location Description', 'APARTMENT'),
#               ('Arrest', 'false'),
#               ('Domestic', 'true')]),
#  OrderedDict([('Date', '09/22/2016 01:00:00 AM'),
#               ('Block', '018XX W ARMITAGE AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'OVER $500'),
#               ('Location Description', 'ALLEY'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '10/19/2016 09:43:00 PM'),
#               ('Block', '024XX W MOFFAT ST'),
#               ('Primary Type', 'ASSAULT'),
#               ('Description', 'SIMPLE'),
#               ('Location Description', 'RESIDENTIAL YARD (FRONT/BACK)'),
#               ('Arrest', 'true'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '06/02/2016 10:00:00 PM'),
#               ('Block', '016XX W CORTLAND ST'),
#               ('Primary Type', 'CRIMINAL DAMAGE'),
#               ('Description', 'TO PROPERTY'),
#               ('Location Description', 'PARKING LOT/GARAGE(NON.RESID.)'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '03/11/2016 03:00:00 PM'),
#               ('Block', '018XX N MARSHFIELD AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'OVER $500'),
#               ('Location Description', 'PARK PROPERTY'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '12/24/2016 12:00:00 PM'),
#               ('Block', '013XX N ARTESIAN AVE'),
#               ('Primary Type', 'BURGLARY'),
#               ('Description', 'FORCIBLE ENTRY'),
#               ('Location Description', 'APARTMENT'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '04/19/2016 02:51:00 PM'),
#               ('Block', '026XX N FAIRFIELD AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'FROM BUILDING'),
#               ('Location Description', 'APARTMENT'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '01/16/2017 07:00:00 PM'),
#               ('Block', '026XX N CALIFORNIA AVE'),
#               ('Primary Type', 'BURGLARY'),
#               ('Description', 'UNLAWFUL ENTRY'),
#               ('Location Description', 'RESIDENCE-GARAGE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '12/01/2016 12:00:00 PM'),
#               ('Block', '032XX W FULLERTON AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'FROM BUILDING'),
#               ('Location Description', 'APARTMENT'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '06/15/2016 03:30:00 AM'),
#               ('Block', '015XX N MAPLEWOOD AVE'),
#               ('Primary Type', 'BURGLARY'),
#               ('Description', 'FORCIBLE ENTRY'),
#               ('Location Description', 'COMMERCIAL / BUSINESS OFFICE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '03/14/2016 12:30:00 PM'),
#               ('Block', '033XX W FULLERTON AVE'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'DOMESTIC BATTERY SIMPLE'),
#               ('Location Description', 'SIDEWALK'),
#               ('Arrest', 'false'),
#               ('Domestic', 'true')]),
#  OrderedDict([('Date', '01/04/2016 03:00:00 PM'),
#               ('Block', '016XX N KIMBALL AVE'),
#               ('Primary Type', 'PUBLIC PEACE VIOLATION'),
#               ('Description', 'ARSON THREAT'),
#               ('Location Description', 'SIDEWALK'),
#               ('Arrest', 'false'),
#               ('Domestic', 'true')]),
#  OrderedDict([('Date', '07/10/2016 04:45:00 PM'),
#               ('Block', '012XX N LUIS MUNOZ MARIN DR E'),
#               ('Primary Type', 'ASSAULT'),
#               ('Description', 'SIMPLE'),
#               ('Location Description', 'PARK PROPERTY'),
#               ('Arrest', 'true'),
#               ('Domestic', 'true')]),
#  OrderedDict([('Date', '12/03/2016 04:00:00 PM'),
#               ('Block', '034XX W BEACH AVE'),
#               ('Primary Type', 'DECEPTIVE PRACTICE'),
#               ('Description', 'FINANCIAL IDENTITY THEFT OVER $ 300'),
#               ('Location Description', 'RESIDENCE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '07/12/2016 05:15:00 PM'),
#               ('Block', '033XX W CRYSTAL ST'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'SIMPLE'),
#               ('Location Description', 'APARTMENT'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '01/09/2017 06:30:00 AM'),
#               ('Block', '027XX W POTOMAC AVE'),
#               ('Primary Type', 'CRIMINAL DAMAGE'),
#               ('Description', 'TO PROPERTY'),
#               ('Location Description', 'RESIDENCE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '03/30/2016 09:00:00 PM'),
#               ('Block', '021XX W NORTH AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'OVER $500'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '02/27/2016 03:00:00 PM'),
#               ('Block', '018XX N CALIFORNIA AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', '$500 AND UNDER'),
#               ('Location Description', 'RESIDENCE-GARAGE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '02/29/2016 08:00:00 AM'),
#               ('Block', '020XX N WHIPPLE ST'),
#               ('Primary Type', 'DECEPTIVE PRACTICE'),
#               ('Description', 'CREDIT CARD FRAUD'),
#               ('Location Description', 'RESIDENCE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '05/26/2016 08:00:00 AM'),
#               ('Block', '020XX N WHIPPLE ST'),
#               ('Primary Type', 'MOTOR VEHICLE THEFT'),
#               ('Description', 'AUTOMOBILE'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '03/16/2016 06:00:00 AM'),
#               ('Block', '021XX W LE MOYNE ST'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'OVER $500'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '07/12/2016 10:00:00 PM'),
#               ('Block', '022XX N SPAULDING AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'OVER $500'),
#               ('Location Description', 'VEHICLE NON-COMMERCIAL'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '12/24/2016 08:30:00 PM'),
#               ('Block', '013XX N WOLCOTT AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'OVER $500'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '01/27/2016 02:05:00 AM'),
#               ('Block', '027XX N WESTERN AVE'),
#               ('Primary Type', 'BURGLARY'),
#               ('Description', 'FORCIBLE ENTRY'),
#               ('Location Description', 'RESTAURANT'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '10/28/2016 06:09:00 PM'),
#               ('Block', '023XX W MC LEAN AVE'),
#               ('Primary Type', 'ROBBERY'),
#               ('Description', 'STRONGARM - NO WEAPON'),
#               ('Location Description', 'RESIDENCE PORCH/HALLWAY'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '06/11/2016 02:00:00 PM'),
#               ('Block', '017XX N WASHTENAW AVE'),
#               ('Primary Type', 'BURGLARY'),
#               ('Description', 'FORCIBLE ENTRY'),
#               ('Location Description', 'RESIDENCE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '02/13/2016 08:50:00 AM'),
#               ('Block', '026XX N ELSTON AVE'),
#               ('Primary Type', 'INTERFERENCE WITH PUBLIC OFFICER'),
#               ('Description', 'INTERFERENCE JUDICIAL PROCESS'),
#               ('Location Description', 'PARKING LOT/GARAGE(NON.RESID.)'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '12/16/2016 08:00:00 PM'),
#               ('Block', '024XX N WESTERN AVE'),
#               ('Primary Type', 'MOTOR VEHICLE THEFT'),
#               ('Description', 'AUTOMOBILE'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '01/14/2017 01:56:00 PM'),
#               ('Block', '013XX N MILWAUKEE AVE'),
#               ('Primary Type', 'CRIMINAL TRESPASS'),
#               ('Description', 'TO VEHICLE'),
#               ('Location Description', 'ALLEY'),
#               ('Arrest', 'true'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '09/17/2016 01:39:00 AM'),
#               ('Block', '012XX N MILWAUKEE AVE'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'AGGRAVATED: HANDGUN'),
#               ('Location Description', 'SIDEWALK'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '09/11/2016 09:50:00 PM'),
#               ('Block', '020XX W DIVISION ST'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'OVER $500'),
#               ('Location Description', 'ALLEY'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '05/30/2016 12:10:00 AM'),
#               ('Block', '033XX W BARRY AVE'),
#               ('Primary Type', 'ROBBERY'),
#               ('Description', 'ARMED: HANDGUN'),
#               ('Location Description', 'SIDEWALK'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '12/24/2016 01:28:00 AM'),
#               ('Block', '016XX N TROY ST'),
#               ('Primary Type', 'BURGLARY'),
#               ('Description', 'ATTEMPT FORCIBLE ENTRY'),
#               ('Location Description', 'RESIDENCE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '02/14/2017 12:01:00 AM'),
#               ('Block', '014XX N CALIFORNIA AVE'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'SIMPLE'),
#               ('Location Description', 'NURSING HOME/RETIREMENT HOME'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '06/19/2016 09:42:00 PM'),
#               ('Block', '034XX W HIRSCH ST'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'SIMPLE'),
#               ('Location Description', 'APARTMENT'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '07/30/2016 02:00:00 AM'),
#               ('Block', '027XX N SPAULDING AVE'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'SIMPLE'),
#               ('Location Description', 'SIDEWALK'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '10/15/2016 08:35:00 PM'),
#               ('Block', '033XX W ARMITAGE AVE'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'SIMPLE'),
#               ('Location Description', 'PARKING LOT/GARAGE(NON.RESID.)'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '12/25/2016 07:40:00 PM'),
#               ('Block', '032XX W ALTGELD ST'),
#               ('Primary Type', 'ROBBERY'),
#               ('Description', 'ARMED: HANDGUN'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '01/18/2017 11:35:00 PM'),
#               ('Block', '028XX W SHAKESPEARE AVE'),
#               ('Primary Type', 'ROBBERY'),
#               ('Description', 'VEHICULAR HIJACKING'),
#               ('Location Description', 'ALLEY'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '11/09/2016 08:00:00 PM'),
#               ('Block', '017XX N MILWAUKEE AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'FROM BUILDING'),
#               ('Location Description', 'RESTAURANT'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '05/05/2016 12:47:00 PM'),
#               ('Block', '023XX N ST LOUIS AVE'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'AGGRAVATED: OTHER DANG WEAPON'),
#               ('Location Description', 'ALLEY'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '10/13/2016 06:50:00 PM'),
#               ('Block', '020XX N MILWAUKEE AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'RETAIL THEFT'),
#               ('Location Description', 'CONVENIENCE STORE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '07/22/2016 04:10:00 AM'),
#               ('Block', '023XX W NORTH AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', '$500 AND UNDER'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '01/26/2016 04:15:00 PM'),
#               ('Block', '021XX W CONCORD PL'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'OVER $500'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '09/28/2016 04:30:00 PM'),
# ...
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '07/19/2016 10:00:00 AM'),
#               ('Block', '028XX N DAWSON AVE'),
#               ('Primary Type', 'DECEPTIVE PRACTICE'),
#               ('Description', 'FINANCIAL IDENTITY THEFT OVER $ 300'),
#               ('Location Description', 'APARTMENT'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '08/25/2016 06:00:00 PM'),
#               ('Block', '031XX W FULLERTON AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'FROM BUILDING'),
#               ('Location Description', 'RESIDENCE-GARAGE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '07/28/2016 12:00:00 PM'),
#               ('Block', '028XX N SACRAMENTO AVE'),
#               ('Primary Type', 'BURGLARY'),
#               ('Description', 'FORCIBLE ENTRY'),
#               ('Location Description', 'RESIDENCE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '02/19/2016 07:45:00 PM'),
#               ('Block', '018XX W WEBSTER AVE'),
#               ('Primary Type', 'CRIMINAL DAMAGE'),
#               ('Description', 'TO VEHICLE'),
#               ('Location Description', 'PARKING LOT/GARAGE(NON.RESID.)'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '02/28/2016 04:45:00 PM'),
#               ('Block', '017XX W NORTH AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'OVER $500'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '02/15/2017 08:38:00 PM'),
#               ('Block', '016XX N DRAKE AVE'),
#               ('Primary Type', 'ROBBERY'),
#               ('Description', 'STRONGARM - NO WEAPON'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '01/24/2016 06:00:00 PM'),
#               ('Block', '024XX N TALMAN AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', '$500 AND UNDER'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '01/09/2017 03:50:00 AM'),
#               ('Block', '028XX W DIVERSEY AVE'),
#               ('Primary Type', 'CRIMINAL DAMAGE'),
#               ('Description', 'TO PROPERTY'),
#               ('Location Description', 'SMALL RETAIL STORE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '11/28/2016 09:20:00 AM'),
#               ('Block', '012XX N CLEAVER ST'),
#               ('Primary Type', 'BURGLARY'),
#               ('Description', 'FORCIBLE ENTRY'),
#               ('Location Description', 'APARTMENT'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '07/17/2016 10:30:00 PM'),
#               ('Block', '029XX N ALBANY AVE'),
#               ('Primary Type', 'MOTOR VEHICLE THEFT'),
#               ('Description', 'AUTOMOBILE'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '08/13/2016 10:30:00 PM'),
#               ('Block', '026XX W WELLINGTON AVE'),
#               ('Primary Type', 'KIDNAPPING'),
#               ('Description', 'KIDNAPPING'),
#               ('Location Description', 'SIDEWALK'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '04/28/2016 09:00:00 PM'),
#               ('Block', '012XX N MILWAUKEE AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'OVER $500'),
#               ('Location Description', 'CTA TRAIN'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '02/08/2017 10:00:00 AM'),
#               ('Block', '017XX N PAULINA ST'),
#               ('Primary Type', 'CRIMINAL DAMAGE'),
#               ('Description', 'TO VEHICLE'),
#               ('Location Description', 'PARKING LOT/GARAGE(NON.RESID.)'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '07/10/2016 04:00:00 PM'),
#               ('Block', '034XX W BELMONT AVE'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'DOMESTIC BATTERY SIMPLE'),
#               ('Location Description', 'SMALL RETAIL STORE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'true')]),
#  OrderedDict([('Date', '12/01/2016 08:00:00 AM'),
#               ('Block', '016XX N KEDZIE AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'OVER $500'),
#               ('Location Description', 'OTHER'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '01/23/2017 10:30:00 AM'),
#               ('Block', '035XX W FULLERTON AVE'),
#               ('Primary Type', 'BURGLARY'),
#               ('Description', 'UNLAWFUL ENTRY'),
#               ('Location Description', 'APARTMENT'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '07/10/2016 01:00:00 AM'),
#               ('Block', '020XX N MILWAUKEE AVE'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'SIMPLE'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '04/16/2016 10:00:00 AM'),
#               ('Block', '013XX N MILWAUKEE AVE'),
#               ('Primary Type', 'DECEPTIVE PRACTICE'),
#               ('Description', 'CREDIT CARD FRAUD'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '10/22/2016 02:30:00 AM'),
#               ('Block', '020XX N MILWAUKEE AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'RETAIL THEFT'),
#               ('Location Description', 'SMALL RETAIL STORE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '01/26/2016 11:00:00 AM'),
#               ('Block', '021XX W EVERGREEN AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'OVER $500'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '09/02/2016 02:00:00 PM'),
#               ('Block', '035XX W NORTH AVE'),
#               ('Primary Type', 'CRIMINAL DAMAGE'),
#               ('Description', 'TO VEHICLE'),
#               ('Location Description', 'PARKING LOT/GARAGE(NON.RESID.)'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '10/07/2016 07:20:00 PM'),
#               ('Block', '023XX W LOGAN BLVD'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'FROM BUILDING'),
#               ('Location Description', 'PARKING LOT/GARAGE(NON.RESID.)'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '07/31/2016 11:20:00 PM'),
#               ('Block', '033XX W EVERGREEN AVE'),
#               ('Primary Type', 'ASSAULT'),
#               ('Description', 'SIMPLE'),
#               ('Location Description', 'SIDEWALK'),
#               ('Arrest', 'true'),
#               ('Domestic', 'true')]),
#  OrderedDict([('Date', '12/19/2016 05:15:00 PM'),
#               ('Block', '022XX N ELSTON AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', '$500 AND UNDER'),
#               ('Location Description', 'OTHER'),
#               ('Arrest', 'true'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '10/19/2016 04:00:00 PM'),
#               ('Block', '014XX N DAMEN AVE'),
#               ('Primary Type', 'ASSAULT'),
#               ('Description', 'AGGRAVATED: OTHER DANG WEAPON'),
#               ('Location Description', 'PARK PROPERTY'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '06/17/2016 08:00:00 AM'),
#               ('Block', '020XX W ST PAUL AVE'),
#               ('Primary Type', 'CRIMINAL DAMAGE'),
#               ('Description', 'TO PROPERTY'),
#               ('Location Description', 'RESIDENCE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '09/26/2016 12:40:00 PM'),
#               ('Block', '015XX N ELK GROVE AVE'),
#               ('Primary Type', 'CRIMINAL DAMAGE'),
#               ('Description', 'TO PROPERTY'),
#               ('Location Description', 'APARTMENT'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '05/16/2016 09:00:00 AM'),
#               ('Block', '027XX W NELSON ST'),
#               ('Primary Type', 'CRIMINAL DAMAGE'),
#               ('Description', 'TO PROPERTY'),
#               ('Location Description', 'RESIDENTIAL YARD (FRONT/BACK)'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '01/31/2017 11:30:00 PM'),
#               ('Block', '016XX W DIVISION ST'),
#               ('Primary Type', 'THEFT'),
#               ('Description', '$500 AND UNDER'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '05/13/2016 03:30:00 PM'),
#               ('Block', '012XX N WESTERN AVE'),
#               ('Primary Type', 'NARCOTICS'),
#               ('Description', 'POSS: CANNABIS 30GMS OR LESS'),
#               ('Location Description', 'SCHOOL, PRIVATE, GROUNDS'),
#               ('Arrest', 'true'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '06/30/2016 01:10:00 AM'),
#               ('Block', '015XX N MAPLEWOOD AVE'),
#               ('Primary Type', 'ASSAULT'),
#               ('Description', 'AGGRAVATED: HANDGUN'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '11/05/2016 07:00:00 PM'),
#               ('Block', '019XX N KIMBALL AVE'),
#               ('Primary Type', 'INTIMIDATION'),
#               ('Description', 'EXTORTION'),
#               ('Location Description', 'RESIDENCE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '09/13/2016 03:43:00 PM'),
#               ('Block', '013XX N MILWAUKEE AVE'),
#               ('Primary Type', 'DECEPTIVE PRACTICE'),
#               ('Description', 'CREDIT CARD FRAUD'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '12/07/2016 03:30:00 PM'),
#               ('Block', '018XX N PAULINA ST'),
#               ('Primary Type', 'OTHER OFFENSE'),
#               ('Description', 'HARASSMENT BY ELECTRONIC MEANS'),
#               ('Location Description', 'RESIDENCE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '05/16/2016 08:00:00 PM'),
#               ('Block', '015XX N OAKLEY BLVD'),
#               ('Primary Type', 'CRIMINAL TRESPASS'),
#               ('Description', 'TO VEHICLE'),
#               ('Location Description', 'ALLEY'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '10/17/2016 05:00:00 PM'),
#               ('Block', '028XX N WESTERN AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'FROM BUILDING'),
#               ('Location Description', 'OTHER'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '01/01/2016 12:01:00 AM'),
#               ('Block', '025XX N SPAULDING AVE'),
#               ('Primary Type', 'OFFENSE INVOLVING CHILDREN'),
#               ('Description', 'OTHER OFFENSE'),
#               ('Location Description', 'RESIDENCE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '02/14/2017 06:30:00 PM'),
#               ('Block', '016XX N HUMBOLDT BLVD'),
#               ('Primary Type', 'CRIMINAL DAMAGE'),
#               ('Description', 'TO VEHICLE'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '02/12/2017 09:00:00 AM'),
#               ('Block', '023XX N LEAVITT ST'),
#               ('Primary Type', 'CRIMINAL DAMAGE'),
#               ('Description', 'TO PROPERTY'),
#               ('Location Description', 'RESIDENCE-GARAGE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '08/26/2016 03:14:00 PM'),
#               ('Block', '013XX N MILWAUKEE AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'FROM BUILDING'),
#               ('Location Description', 'SMALL RETAIL STORE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '07/21/2016 06:25:00 PM'),
#               ('Block', '012XX N ASHLAND AVE'),
#               ('Primary Type', 'DECEPTIVE PRACTICE'),
#               ('Description', 'FRAUD OR CONFIDENCE GAME'),
#               ('Location Description', 'RESTAURANT'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '09/06/2016 02:00:00 PM'),
#               ('Block', '018XX N MILWAUKEE AVE'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'FROM BUILDING'),
#               ('Location Description', 'RESIDENCE-GARAGE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '06/13/2016 07:45:00 PM'),
#               ('Block', '024XX N ST LOUIS AVE'),
#               ('Primary Type', 'BURGLARY'),
#               ('Description', 'UNLAWFUL ENTRY'),
#               ('Location Description', 'RESIDENCE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '07/28/2016 11:45:00 PM'),
#               ('Block', '031XX N BERNARD ST'),
#               ('Primary Type', 'ASSAULT'),
#               ('Description', 'SIMPLE'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '05/11/2016 10:10:00 PM'),
#               ('Block', '023XX N ROCKWELL ST'),
#               ('Primary Type', 'ROBBERY'),
#               ('Description', 'STRONGARM - NO WEAPON'),
#               ('Location Description', 'RESIDENTIAL YARD (FRONT/BACK)'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '08/24/2016 08:00:00 PM'),
#               ('Block', '029XX N SAWYER AVE'),
#               ('Primary Type', 'CRIMINAL DAMAGE'),
#               ('Description', 'TO VEHICLE'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '07/15/2016 05:00:00 PM'),
#               ('Block', '018XX N SAWYER AVE'),
#               ('Primary Type', 'BURGLARY'),
#               ('Description', 'FORCIBLE ENTRY'),
#               ('Location Description', 'OTHER'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '01/02/2016 12:16:00 AM'),
#               ('Block', '030XX N KEDZIE AVE'),
#               ('Primary Type', 'LIQUOR LAW VIOLATION'),
#               ('Description', 'ILLEGAL CONSUMPTION BY MINOR'),
#               ('Location Description', 'SIDEWALK'),
#               ('Arrest', 'true'),
#               ('Domestic', 'false')]),
#  OrderedDict([('Date', '05/07/2016 11:50:00 AM'),
#               ('Block', '020XX W SCHILLER ST'),
#               ('Primary Type', 'THEFT'),
#               ('Description', '$500 AND UNDER'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false')])]

# %% [markdown]
# #### Determine the Arrests by District by Year

# %% [markdown]
# Using **crimes_by_district** dictionary from the previous cell, we'll now determine the number arrests in each City district for each year.

# %%
# Loop over the crimes_by_district
for district, crimes in crimes_by_district.items():
    print(district)
    year_count = Counter()
    for crime in crimes:
        if crime['Arrest'] == 'true':
            year = datetime.strptime(crime['Date'], '%m/%d/%Y %I:%M:%S %p').year
            year_count[year] += 1
            
    print(year_count)
# Out:
# 14
# Counter({2016: 59, 2017: 8})
# 24
# Counter({2016: 51, 2017: 10})
# 6
# Counter({2016: 157, 2017: 32})
# 15
# Counter({2016: 154, 2017: 16})
# 12
# Counter({2016: 72, 2017: 9})
# 7
# Counter({2016: 181, 2017: 27})
# 1
# Counter({2016: 124, 2017: 15})
# 11
# Counter({2016: 275, 2017: 53})
# 18
# Counter({2016: 92, 2017: 17})
# 22
# Counter({2016: 78, 2017: 12})
# 5
# Counter({2016: 149, 2017: 30})
# 16
# Counter({2016: 66, 2017: 9})
# 9
# Counter({2016: 116, 2017: 17})
# 8
# Counter({2016: 124, 2017: 26})
# 3
# Counter({2016: 98, 2017: 18})
# 2
# Counter({2016: 84, 2017: 15})
# 19
# Counter({2016: 88, 2017: 11})
# 10
# Counter({2016: 144, 2017: 20})
# 4
# Counter({2016: 134, 2017: 15})
# 17
# Counter({2016: 38, 2017: 5})
# 20
# Counter({2016: 27, 2017: 8})
# 25
# Counter({2016: 150, 2017: 26})
# 31
# Counter({2016: 1})

# %% [markdown]
# #### Unique Crimes by City Block

# %% [markdown]
# The task in this cell is to get a unique list of crimes that have occurred on a couple of the blocks that have been selected for you to learn more about.

# %%
csvfile = open('crime_sampler.csv', 'r')

crimes_by_block = defaultdict(list)

for row in csv.DictReader(csvfile):
    # Pop the district from each row: district
    block = row.pop('Block')
    # Append the rest of the data to the list for proper district
    crimes_by_block[block].append(row['Primary Type'])

# %%
crimes_by_block['070XX S SOUTH SHORE DR']
# Out:
# ['THEFT', 'THEFT', 'ROBBERY']

# %%
len(crimes_by_block)
# Out:
# 9195

# %%
# First block
n_state_st_crimes = set(crimes_by_block['001XX N STATE ST'])
print(n_state_st_crimes)

# Second block
w_terminal_st_crimes = set(crimes_by_block['0000X W TERMINAL ST'])
print(w_terminal_st_crimes)

#Differences between the two blocks
crime_differences = n_state_st_crimes - w_terminal_st_crimes
print(crime_differences)
# Out:
# {'ASSAULT', 'CRIMINAL DAMAGE', 'DECEPTIVE PRACTICE', 'CRIMINAL TRESPASS', 'OTHER OFFENSE', 'ROBBERY', 'THEFT', 'BATTERY'}
# {'NARCOTICS', 'ASSAULT', 'CRIMINAL DAMAGE', 'DECEPTIVE PRACTICE', 'CRIMINAL TRESPASS', 'PUBLIC PEACE VIOLATION', 'OTHER OFFENSE', 'THEFT'}
# {'BATTERY', 'ROBBERY'}
